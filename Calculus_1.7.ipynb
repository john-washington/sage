# %% [markdown]
# **Limits, Continuity, and Differentiablility**
#
# **Preview Activity 1.7**

# %%
plot(sin(pi/x), (x, -pi, pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# **Preview Activity 1.7**
