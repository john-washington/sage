# %%
url="https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv"
url
# Out:
# "https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv"

# %%
#url="https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv"
#url="https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv"
#url="https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv"
#url="https://covidtracking.com/data/download/california-history.csv"
url="https://covidtracking.com/data/download/national-history.csv"
# Out:
# "https://covidtracking.com/data/download/national-history.csv"

# %% [markdown]
# **Exploring data on COVID-19**

# %%
methods(*)
# Out:
# # 309 methods for generic function "*" from Base:
#    [1] *(x::T, y::T) where T<:Union{Int128, UInt128}
#      @ int.jl:1027
#    [2] *(x::T, y::T) where T<:Union{Int128, Int16, Int32, Int64, Int8, UInt128, UInt16, UInt32, UInt64, UInt8}
#      @ int.jl:88
#    [3] *(x::T, y::T) where T<:Union{Float16, Float32, Float64}
#      @ float.jl:410
#    [4] *(s1::Union{AbstractChar, AbstractString}, ss::Union{AbstractChar, AbstractString}...)
#      @ strings/basic.jl:260
#    [5] *(d::Union{AbstractChar, AbstractString}, x::Missing)
#      @ missing.jl:183
#    [6] *(c::Union{UInt16, UInt32, UInt64, UInt8}, x::BigInt)
#      @ Base.GMP gmp.jl:550
#    [7] *(c::Union{Int16, Int32, Int64, Int8}, x::BigInt)
#      @ Base.GMP gmp.jl:552
#    [8] *(c::Union{UInt16, UInt32, UInt64, UInt8}, x::BigFloat)
#      @ Base.MPFR mpfr.jl:407
#    [9] *(c::Union{Int16, Int32, Int64, Int8}, x::BigFloat)
#      @ Base.MPFR mpfr.jl:415
#   [10] *(c::Union{Float16, Float32, Float64}, x::BigFloat)
#      @ Base.MPFR mpfr.jl:423
#   [11] *(A::StridedMatrix{T}, x::StridedVector{S}) where {T<:Union{Float32, Float64, ComplexF64, ComplexF32}, S<:Real}
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:49
#   [12] *(A::Union{LinearAlgebra.Adjoint{var"#s970", <:StridedMatrix{T} where T}, LinearAlgebra.Transpose{var"#s970", <:StridedMatrix{T} where T}, StridedMatrix{var"#s970"}} where var"#s970"<:Union{Float32, Float64}, B::Union{LinearAlgebra.Adjoint{var"#s969", <:StridedMatrix{T} where T}, LinearAlgebra.Transpose{var"#s969", <:StridedMatrix{T} where T}, StridedMatrix{var"#s969"}} where var"#s969"<:Union{Float32, Float64})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:146
#   [13] *(A::Union{LinearAlgebra.Adjoint{var"#s970", <:StridedMatrix{T} where T}, LinearAlgebra.Transpose{var"#s970", <:StridedMatrix{T} where T}, StridedMatrix{var"#s970"}} where var"#s970"<:Union{ComplexF64, ComplexF32}, B::Union{LinearAlgebra.Adjoint{var"#s969", <:StridedMatrix{T} where T}, LinearAlgebra.Transpose{var"#s969", <:StridedMatrix{T} where T}, StridedMatrix{var"#s969"}} where var"#s969"<:Union{ComplexF64, ComplexF32})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:152
#   [14] *(A::StridedMatrix{var"#s970"} where var"#s970"<:Union{ComplexF64, ComplexF32}, B::Union{LinearAlgebra.Adjoint{var"#s969", <:StridedMatrix{T} where T}, LinearAlgebra.Transpose{var"#s969", <:StridedMatrix{T} where T}, StridedMatrix{var"#s969"}} where var"#s969"<:Union{Float32, Float64})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:165
#   [15] *(A::Union{LinearAlgebra.Adjoint{var"#s970", <:StridedMatrix{T} where T}, LinearAlgebra.Transpose{var"#s970", <:StridedMatrix{T} where T}} where var"#s970"<:Union{ComplexF64, ComplexF32}, B::Union{LinearAlgebra.Adjoint{var"#s969", <:StridedMatrix{T} where T}, LinearAlgebra.Transpose{var"#s969", <:StridedMatrix{T} where T}, StridedMatrix{var"#s969"}} where var"#s969"<:Union{Float32, Float64})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:171
#   [16] *(A::StridedMatrix{var"#s970"} where var"#s970"<:Union{Float32, Float64}, B::StridedMatrix{var"#s969"} where var"#s969"<:Union{ComplexF64, ComplexF32})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:178
#   [17] *(A::Union{LinearAlgebra.Adjoint{var"#s970", <:StridedMatrix{T} where T}, LinearAlgebra.Transpose{var"#s970", <:StridedMatrix{T} where T}} where var"#s970"<:Union{Float32, Float64}, B::StridedMatrix{var"#s969"} where var"#s969"<:Union{ComplexF64, ComplexF32})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:185
#   [18] *(A::Union{LinearAlgebra.Adjoint{var"#s970", <:StridedMatrix{T} where T}, LinearAlgebra.Transpose{var"#s970", <:StridedMatrix{T} where T}, StridedMatrix{var"#s970"}} where var"#s970"<:Union{Float32, Float64}, B::Union{LinearAlgebra.Adjoint{var"#s969", <:StridedMatrix{T} where T}, LinearAlgebra.Transpose{var"#s969", <:StridedMatrix{T} where T}} where var"#s969"<:Union{ComplexF64, ComplexF32})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:186
#   [19] *(α::Union{Real, Complex}, vt::Union{LinearAlgebra.Adjoint{var"#s970", var"#s9701"}, LinearAlgebra.Transpose{var"#s970", var"#s9701"}} where {var"#s970"<:Union{Real, Complex}, var"#s9701"<:(AbstractVector)}, C::AbstractMatrix{<:Union{Real, Complex}}, D::AbstractMatrix{<:Union{Real, Complex}})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:1218
#   [20] *(A::StridedMatrix{T} where T, Q::LinearAlgebra.AbstractQ)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/qr.jl:775
#   [21] *(A::StridedMatrix{T} where T, adjB::LinearAlgebra.Adjoint{<:Any, <:LinearAlgebra.AbstractQ})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/qr.jl:822
#   [22] *(A::StridedVecOrMat, adjQ::LinearAlgebra.Adjoint{<:Any, <:LinearAlgebra.LQPackedQ})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/lq.jl:269
#   [23] *(A::StridedVecOrMat, Q::LinearAlgebra.LQPackedQ)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/lq.jl:293
#   [24] *(A::Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Symmetric{T, S}} where {T, S}, B::Union{LinearAlgebra.Hermitian{T, S}, LinearAlgebra.Symmetric{T, S}} where {T, S})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/symmetric.jl:576
#   [25] *(A::Union{LinearAlgebra.UnitUpperTriangular{T, S} where S<:AbstractMatrix{T}, LinearAlgebra.UpperTriangular{T, S} where S<:AbstractMatrix{T}} where T, B::LinearAlgebra.Bidiagonal)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/bidiag.jl:647
#   [26] *(A::Union{LinearAlgebra.LowerTriangular{T, S} where S<:AbstractMatrix{T}, LinearAlgebra.UnitLowerTriangular{T, S} where S<:AbstractMatrix{T}} where T, B::LinearAlgebra.Bidiagonal)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/bidiag.jl:653
#   [27] *(A::Union{LinearAlgebra.Bidiagonal, LinearAlgebra.Tridiagonal}, B::LinearAlgebra.Diagonal)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/bidiag.jl:671
#   [28] *(A::Union{LinearAlgebra.Bidiagonal, LinearAlgebra.SymTridiagonal, LinearAlgebra.Tridiagonal}, B::Union{LinearAlgebra.Bidiagonal, LinearAlgebra.SymTridiagonal, LinearAlgebra.Tridiagonal})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/bidiag.jl:691
#   [29] *(U::Union{LinearAlgebra.UnitUpperTriangular{T, S} where S<:AbstractMatrix{T}, LinearAlgebra.UpperTriangular{T, S} where S<:AbstractMatrix{T}} where T, H::LinearAlgebra.UpperHessenberg)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/hessenberg.jl:132
#   [30] *(A::Union{LinearAlgebra.Bidiagonal, LinearAlgebra.SymTridiagonal, LinearAlgebra.Tridiagonal}, Q::LinearAlgebra.AbstractQ)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:338
#   [31] *(A::Union{LinearAlgebra.Bidiagonal, LinearAlgebra.SymTridiagonal, LinearAlgebra.Tridiagonal}, Q::LinearAlgebra.Adjoint{<:Any, <:LinearAlgebra.AbstractQ})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:339
#   [32] *(X::StridedArray{P}, y::Real) where P<:Dates.Period
#      @ Dates ~/julia/usr/share/julia/stdlib/v1.9/Dates/src/deprecated.jl:44
#   [33] *(x::Union{SparseArrays.AbstractCompressedVector{Tv, Ti}, SubArray{Tv, 1, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, Int64}, false}, SubArray{Tv, 1, <:SparseArrays.AbstractSparseVector{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}}, false}} where {Tv, Ti}, a::Number)
#      @ SparseArrays ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/sparsevector.jl:1650
#   [34] *(A::Union{SparseArrays.AbstractSparseMatrixCSC{TA, Ti}, SubArray{TA, 2, <:SparseArrays.AbstractSparseMatrixCSC{TA, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange} where Ti, x::Union{StridedVector, BitVector}) where TA
#      @ SparseArrays ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:50
#   [35] *(A::Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange, LinearAlgebra.LowerTriangular{Tv, <:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange}}, LinearAlgebra.UpperTriangular{Tv, <:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange}}} where {Tv, Ti}, B::SubArray{Tv, 1, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, Int64}, false} where {Tv, Ti})
#      @ SparseArrays ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:151
#   [36] *(A::Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange, LinearAlgebra.LowerTriangular{Tv, <:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange}}, LinearAlgebra.UpperTriangular{Tv, <:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange}}} where {Tv, Ti}, B::SubArray{Tv, 1, <:SparseArrays.AbstractSparseVector{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}}, false} where {Tv, Ti})
#      @ SparseArrays ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:152
#   [37] *(A::Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange} where {Tv, Ti}, B::Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange} where {Tv, Ti})
#      @ SparseArrays ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:153
#   [38] *(A::Union{LinearAlgebra.LowerTriangular{Tv, <:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange}}, LinearAlgebra.UpperTriangular{Tv, <:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange}}} where {Tv, Ti}, B::Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange} where {Tv, Ti})
#      @ SparseArrays ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:154
#   [39] *(X::Union{LinearAlgebra.Adjoint{<:Any, <:Union{LinearAlgebra.LowerTriangular, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix, BitMatrix}}, LinearAlgebra.LowerTriangular, LinearAlgebra.Transpose{<:Any, <:Union{LinearAlgebra.LowerTriangular, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix, BitMatrix}}, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix, BitMatrix}, A::Union{SparseArrays.AbstractSparseMatrixCSC{TvA, Ti}, SubArray{TvA, 2, <:SparseArrays.AbstractSparseMatrixCSC{TvA, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange} where Ti) where TvA
#      @ SparseArrays ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:114
#   [40] *(A::Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange} where {Tv, Ti}, B::Union{LinearAlgebra.LowerTriangular{Tv, <:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange}}, LinearAlgebra.UpperTriangular{Tv, <:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange}}} where {Tv, Ti})
#      @ SparseArrays ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:155
#   [41] *(A::Union{SparseArrays.AbstractSparseMatrixCSC{TA, Ti}, SubArray{TA, 2, <:SparseArrays.AbstractSparseMatrixCSC{TA, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange} where Ti, B::Union{LinearAlgebra.Adjoint{<:Any, <:Union{LinearAlgebra.LowerTriangular, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix, BitMatrix}}, LinearAlgebra.LowerTriangular, LinearAlgebra.Transpose{<:Any, <:Union{LinearAlgebra.LowerTriangular, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix, BitMatrix}}, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix, BitMatrix}) where TA
#      @ SparseArrays ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:52
#   [42] *(A::Union{LinearAlgebra.LowerTriangular{Tv, <:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange}}, LinearAlgebra.UpperTriangular{Tv, <:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange}}} where {Tv, Ti}, B::Union{LinearAlgebra.LowerTriangular{Tv, <:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange}}, LinearAlgebra.UpperTriangular{Tv, <:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange}}} where {Tv, Ti})
#      @ SparseArrays ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:156
#   [43] *(A::Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange, LinearAlgebra.LowerTriangular{Tv, <:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange}}, LinearAlgebra.UpperTriangular{Tv, <:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange}}} where {Tv, Ti}, B::LinearAlgebra.Adjoint{<:Any, <:SparseArrays.AbstractSparseMatrixCSC})
#      @ SparseArrays ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:157
#   [44] *(X::Union{LinearAlgebra.Adjoint{<:Any, <:Union{LinearAlgebra.LowerTriangular, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix, BitMatrix}}, LinearAlgebra.LowerTriangular, LinearAlgebra.Transpose{<:Any, <:Union{LinearAlgebra.LowerTriangular, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix, BitMatrix}}, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix, BitMatrix}, adjA::LinearAlgebra.Adjoint{<:Any, <:SparseArrays.AbstractSparseMatrixCSC})
#      @ SparseArrays ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:139
#   [45] *(A::Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange, LinearAlgebra.LowerTriangular{Tv, <:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange}}, LinearAlgebra.UpperTriangular{Tv, <:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange}}} where {Tv, Ti}, B::LinearAlgebra.Transpose{<:Any, <:SparseArrays.AbstractSparseMatrixCSC})
#      @ SparseArrays ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:158
#   [46] *(X::Union{LinearAlgebra.Adjoint{<:Any, <:Union{LinearAlgebra.LowerTriangular, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix, BitMatrix}}, LinearAlgebra.LowerTriangular, LinearAlgebra.Transpose{<:Any, <:Union{LinearAlgebra.LowerTriangular, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix, BitMatrix}}, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix, BitMatrix}, tA::LinearAlgebra.Transpose{<:Any, <:SparseArrays.AbstractSparseMatrixCSC})
#      @ SparseArrays ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:141
#   [47] *(A::Union{SparseArrays.SparseMatrixCSC{Float64, Ti}, SparseArrays.SparseVector{Float64, Ti}}, B::LinearAlgebra.Symmetric{Float64, SparseArrays.SparseMatrixCSC{Float64, Ti}}) where Ti
#      @ SparseArrays.CHOLMOD ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/solvers/cholmod.jl:1690
#   [48] *(A::Union{SparseArrays.SparseMatrixCSC{ComplexF64, Ti}, SparseArrays.SparseVector{ComplexF64, Ti}}, B::LinearAlgebra.Hermitian{ComplexF64, SparseArrays.SparseMatrixCSC{ComplexF64, Ti}}) where Ti
#      @ SparseArrays.CHOLMOD ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/solvers/cholmod.jl:1692
#   [49] *(A::Union{SparseArrays.SparseMatrixCSC{Float64, Ti}, SparseArrays.SparseVector{Float64, Ti}}, B::LinearAlgebra.Hermitian{Float64, SparseArrays.SparseMatrixCSC{Float64, Ti}}) where Ti
#      @ SparseArrays.CHOLMOD ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/solvers/cholmod.jl:1694
#   [50] *(x::Rational, y::Integer)
#      @ rational.jl:352
#   [51] *(A::LinearAlgebra.LQPackedQ, B::StridedVecOrMat)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/lq.jl:206
#   [52] *(A::LinearAlgebra.LQPackedQ, adjB::LinearAlgebra.Adjoint{<:Any, <:StridedVecOrMat})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/lq.jl:230
#   [53] *(A::LinearAlgebra.LowerTriangular, x::Number)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/triangular.jl:849
#   [54] *(A::LinearAlgebra.LowerTriangular, B::LinearAlgebra.LowerTriangular)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/triangular.jl:1291
#   [55] *(A::LinearAlgebra.LowerTriangular, B::LinearAlgebra.UnitLowerTriangular)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/triangular.jl:1305
#   [56] *(A::LinearAlgebra.LowerTriangular, D::LinearAlgebra.Diagonal)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/diagonal.jl:540
#   [57] *(A::AbstractVector, R::LinearAlgebra.AbstractRotation)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/givens.jl:19
#   [58] *(A::AbstractMatrix, R::LinearAlgebra.AbstractRotation)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/givens.jl:20
#   [59] *(H::LinearAlgebra.UpperHessenberg, x::Number)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/hessenberg.jl:119
#   [60] *(H::LinearAlgebra.UpperHessenberg, x::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/hessenberg.jl:119
#   [61] *(H::LinearAlgebra.UpperHessenberg, x::LinearAlgebra.Diagonal)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/hessenberg.jl:119
#   [62] *(H::LinearAlgebra.UpperHessenberg, U::Union{LinearAlgebra.UnitUpperTriangular{T, S} where S<:AbstractMatrix{T}, LinearAlgebra.UpperTriangular{T, S} where S<:AbstractMatrix{T}} where T)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/hessenberg.jl:126
#   [63] *(H::LinearAlgebra.UpperHessenberg, B::LinearAlgebra.Bidiagonal)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/hessenberg.jl:165
#   [64] *(A::LinearAlgebra.Tridiagonal, B::Number)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/tridiag.jl:757
#   [65] *(A::LinearAlgebra.SymTridiagonal, B::Number)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/tridiag.jl:210
#   [66] *(A::LinearAlgebra.SymTridiagonal, B::LinearAlgebra.Diagonal)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/bidiag.jl:686
#   [67] *(A::LinearAlgebra.AbstractQ, b::StridedVector{T} where T)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/qr.jl:656
#   [68] *(A::LinearAlgebra.AbstractQ, B::StridedMatrix{T} where T)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/qr.jl:668
#   [69] *(A::LinearAlgebra.AbstractQ, b::Number)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/qr.jl:681
#   [70] *(Q::LinearAlgebra.AbstractQ, adjB::LinearAlgebra.Adjoint{<:Any, <:StridedVecOrMat})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/qr.jl:730
#   [71] *(Q::LinearAlgebra.AbstractQ, B::LinearAlgebra.AbstractTriangular)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:309
#   [72] *(Q::LinearAlgebra.AbstractQ, B::Union{LinearAlgebra.Bidiagonal, LinearAlgebra.SymTridiagonal, LinearAlgebra.Tridiagonal})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:311
#   [73] *(Q::LinearAlgebra.AbstractQ, B::LinearAlgebra.Diagonal)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:313
#   [74] *(Q::LinearAlgebra.AbstractQ, B::LinearAlgebra.AbstractQ)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:343
#   [75] *(Q::LinearAlgebra.AbstractQ, B::LinearAlgebra.Adjoint{<:Any, <:LinearAlgebra.AbstractQ})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:345
#   [76] *(G1::LinearAlgebra.Givens{S}, G2::LinearAlgebra.Givens{T}) where {S, T}
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/givens.jl:416
#   [77] *(G::LinearAlgebra.Givens{T}...) where T
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/givens.jl:420
#   [78] *(G::LinearAlgebra.Givens{S}, R::LinearAlgebra.Rotation{T}) where {S, T}
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/givens.jl:421
#   [79] *(a::Number, x::Union{SparseArrays.AbstractCompressedVector{Tv, Ti}, SubArray{Tv, 1, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, Int64}, false}, SubArray{Tv, 1, <:SparseArrays.AbstractSparseVector{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}}, false}} where {Tv, Ti})
#      @ SparseArrays ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/sparsevector.jl:1652
#   [80] *(v::Number, x::Base.TwicePrecision)
#      @ twiceprecision.jl:317
#   [81] *(x::Number, A::LinearAlgebra.UpperTriangular)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/triangular.jl:859
#   [82] *(x::Number, A::LinearAlgebra.LowerTriangular)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/triangular.jl:859
#   [83] *(x::Number, H::LinearAlgebra.UpperHessenberg)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/hessenberg.jl:120
#   [84] *(B::Number, A::LinearAlgebra.Bidiagonal)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/bidiag.jl:394
#   [85] *(B::Number, A::LinearAlgebra.Tridiagonal)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/tridiag.jl:758
#   [86] *(B::Number, A::LinearAlgebra.SymTridiagonal)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/tridiag.jl:211
#   [87] *(a::Number, B::LinearAlgebra.AbstractQ)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/qr.jl:781
#   [88] *(x::S, F::LinearAlgebra.Hessenberg{<:Any, <:AbstractMatrix{T}}) where {T, S<:Number}
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/hessenberg.jl:636
#   [89] *(x::Number, D::LinearAlgebra.Diagonal)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/diagonal.jl:202
#   [90] *(x::Number, A::LinearAlgebra.UnitUpperTriangular)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/triangular.jl:861
#   [91] *(x::Number, A::LinearAlgebra.UnitLowerTriangular)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/triangular.jl:861
#   [92] *(x::Number, J::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/uniformscaling.jl:263
#   [93] *(x::Number, A::LinearAlgebra.Symmetric)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/symmetric.jl:605
#   [94] *(::Number, ::Missing)
#      @ missing.jl:124
#   [95] *(x::Base.TwicePrecision{<:Union{Float16, Float32, Float64}}, v::Integer)
#      @ twiceprecision.jl:311
#   [96] *(x::Base.TwicePrecision, v::Number)
#      @ twiceprecision.jl:307
#   [97] *(x::Base.TwicePrecision{T}, y::Base.TwicePrecision{T}) where T
#      @ twiceprecision.jl:319
#   [98] *(x::Base.TwicePrecision, y::Base.TwicePrecision)
#      @ twiceprecision.jl:324
#   [99] *(A::LinearAlgebra.UpperTriangular, x::Number)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/triangular.jl:849
#  [100] *(A::LinearAlgebra.UpperTriangular, B::LinearAlgebra.UpperTriangular)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/triangular.jl:1319
#  [101] *(A::LinearAlgebra.UpperTriangular, B::LinearAlgebra.UnitUpperTriangular)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/triangular.jl:1333
#  [102] *(A::LinearAlgebra.UpperTriangular, D::LinearAlgebra.Diagonal)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/diagonal.jl:540
#  [103] *(R::LinearAlgebra.AbstractRotation, A::AbstractVector)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/givens.jl:12
#  [104] *(R::LinearAlgebra.AbstractRotation, A::AbstractMatrix)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/givens.jl:13
#  [105] *(A::LinearAlgebra.AbstractTriangular, Q::LinearAlgebra.AbstractQ)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:336
#  [106] *(A::LinearAlgebra.AbstractTriangular, Q::LinearAlgebra.Adjoint{<:Any, <:LinearAlgebra.AbstractQ})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:337
#  [107] *(A::LinearAlgebra.UnitLowerTriangular, x::Number)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/triangular.jl:851
#  [108] *(A::LinearAlgebra.UnitLowerTriangular, B::LinearAlgebra.LowerTriangular)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/triangular.jl:1298
#  [109] *(A::LinearAlgebra.UnitLowerTriangular, B::LinearAlgebra.UnitLowerTriangular)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/triangular.jl:1312
#  [110] *(A::LinearAlgebra.UnitLowerTriangular, D::LinearAlgebra.Diagonal)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/diagonal.jl:541
#  [111] *(r::StepRangeLen{<:Real, <:Base.TwicePrecision}, x::Real)
#      @ twiceprecision.jl:538
#  [112] *(Q::SparseArrays.SPQR.QRSparseQ, B::SparseArrays.SparseMatrixCSC)
#      @ SparseArrays.SPQR ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/solvers/spqr.jl:287
#  [113] *(A::SparseArrays.SparseMatrixCSC, Q::SparseArrays.SPQR.QRSparseQ)
#      @ SparseArrays.SPQR ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/solvers/spqr.jl:288
#  [114] *(A::SparseArrays.AbstractSparseMatrixCSC, x::SparseArrays.AbstractSparseVector)
#      @ SparseArrays ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/sparsevector.jl:1946
#  [115] *(A::Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange, LinearAlgebra.LowerTriangular{Tv, <:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange}}, LinearAlgebra.UpperTriangular{Tv, <:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange}}} where {Tv, Ti}, B::SparseArrays.AbstractSparseVector)
#      @ SparseArrays ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:150
#  [116] *(A::Union{LinearAlgebra.LowerTriangular{Ta, S} where S<:AbstractMatrix{Ta}, LinearAlgebra.UnitLowerTriangular{Ta, S} where S<:AbstractMatrix{Ta}, LinearAlgebra.UnitUpperTriangular{Ta, S} where S<:AbstractMatrix{Ta}, LinearAlgebra.UpperTriangular{Ta, S} where S<:AbstractMatrix{Ta}, StridedArray{Ta, 2}}, x::SparseArrays.AbstractSparseVector{Tx}) where {Ta, Tx}
#      @ SparseArrays ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/sparsevector.jl:1740
#  [117] *(A::LinearAlgebra.Bidiagonal, B::Number)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/bidiag.jl:393
#  [118] *(A::LinearAlgebra.Bidiagonal, B::Union{LinearAlgebra.UnitUpperTriangular{T, S} where S<:AbstractMatrix{T}, LinearAlgebra.UpperTriangular{T, S} where S<:AbstractMatrix{T}} where T)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/bidiag.jl:659
#  [119] *(A::LinearAlgebra.Bidiagonal, B::Union{LinearAlgebra.LowerTriangular{T, S} where S<:AbstractMatrix{T}, LinearAlgebra.UnitLowerTriangular{T, S} where S<:AbstractMatrix{T}} where T)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/bidiag.jl:665
#  [120] *(B::LinearAlgebra.Bidiagonal, H::LinearAlgebra.UpperHessenberg)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/hessenberg.jl:170
#  [121] *(A::LinearAlgebra.Symmetric, x::Number)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/symmetric.jl:604
#  [122] *(A::LinearAlgebra.Symmetric{Float64, SparseArrays.SparseMatrixCSC{Float64, Ti}}, B::Union{SparseArrays.SparseMatrixCSC{Float64, Ti}, SparseArrays.SparseVector{Float64, Ti}}) where Ti
#      @ SparseArrays.CHOLMOD ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/solvers/cholmod.jl:1683
#  [123] *(index::CartesianIndex, a::Integer)
#      @ Base.IteratorsMD multidimensional.jl:121
#  [124] *(y::Integer, x::Rational)
#      @ rational.jl:356
#  [125] *(a::Integer, index::CartesianIndex{N}) where N
#      @ Base.IteratorsMD multidimensional.jl:120
#  [126] *(r::AbstractRange{<:Real}, x::Dates.Period)
#      @ Dates ~/julia/usr/share/julia/stdlib/v1.9/Dates/src/ranges.jl:68
#  [127] *(A::AbstractArray, B::Dates.Period)
#      @ Dates ~/julia/usr/share/julia/stdlib/v1.9/Dates/src/periods.jl:94
#  [128] *(F::LinearAlgebra.Hessenberg{<:Any, <:AbstractMatrix{T}}, x::S) where {T, S<:Number}
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/hessenberg.jl:628
#  [129] *(A::LinearAlgebra.Diagonal, B::Union{LinearAlgebra.Bidiagonal, LinearAlgebra.Tridiagonal})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/bidiag.jl:676
#  [130] *(D::LinearAlgebra.Diagonal, A::LinearAlgebra.UpperTriangular)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/diagonal.jl:544
#  [131] *(D::LinearAlgebra.Diagonal, A::LinearAlgebra.LowerTriangular)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/diagonal.jl:544
#  [132] *(A::LinearAlgebra.Diagonal, Q::LinearAlgebra.AbstractQ)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:340
#  [133] *(x::LinearAlgebra.Diagonal, H::LinearAlgebra.UpperHessenberg)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/hessenberg.jl:120
#  [134] *(A::LinearAlgebra.Diagonal, B::LinearAlgebra.SymTridiagonal)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/bidiag.jl:681
#  [135] *(D::LinearAlgebra.Diagonal, x::Number)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/diagonal.jl:203
#  [136] *(Da::LinearAlgebra.Diagonal, Db::LinearAlgebra.Diagonal)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/diagonal.jl:237
#  [137] *(Da::LinearAlgebra.Diagonal, Db::LinearAlgebra.Diagonal, Dc::LinearAlgebra.Diagonal)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/diagonal.jl:358
#  [138] *(D::LinearAlgebra.Diagonal, adjQ::LinearAlgebra.Adjoint{<:Any, <:Union{LinearAlgebra.QRCompactWYQ, LinearAlgebra.QRPackedQ}})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/diagonal.jl:260
#  [139] *(A::LinearAlgebra.Diagonal, Q::LinearAlgebra.Adjoint{<:Any, <:LinearAlgebra.AbstractQ})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:341
#  [140] *(D::LinearAlgebra.Diagonal, A::Union{LinearAlgebra.Adjoint{T, var"#s970"}, LinearAlgebra.Transpose{T, var"#s970"}} where {T, var"#s970"<:(AbstractMatrix)})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/diagonal.jl:263
#  [141] *(D::LinearAlgebra.Diagonal, A::LinearAlgebra.UnitUpperTriangular)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/diagonal.jl:545
#  [142] *(D::LinearAlgebra.Diagonal, A::LinearAlgebra.UnitLowerTriangular)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/diagonal.jl:545
#  [143] *(D::LinearAlgebra.Diagonal, A::LinearAlgebra.AbstractTriangular)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/diagonal.jl:801
#  [144] *(D::LinearAlgebra.Diagonal, A::AbstractMatrix)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/diagonal.jl:249
#  [145] *(Da::LinearAlgebra.Diagonal, A::AbstractMatrix, Db::LinearAlgebra.Diagonal)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/diagonal.jl:352
#  [146] *(D::LinearAlgebra.Diagonal, V::AbstractVector)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/diagonal.jl:242
#  [147] *(x::Real, r::StepRangeLen{<:Real, <:Base.TwicePrecision})
#      @ twiceprecision.jl:536
#  [148] *(x::Real, A::LinearAlgebra.Hermitian)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/symmetric.jl:607
#  [149] *(α::Union{Real, Complex}, B::AbstractMatrix{<:Union{Real, Complex}}, C::AbstractVector{<:Union{Real, Complex}})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:1157
#  [150] *(α::Union{Real, Complex}, B::AbstractMatrix{<:Union{Real, Complex}}, C::AbstractMatrix{<:Union{Real, Complex}})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:1159
#  [151] *(α::Union{Real, Complex}, B::AbstractMatrix{<:Union{Real, Complex}}, C::AbstractMatrix{<:Union{Real, Complex}}, D::AbstractMatrix{<:Union{Real, Complex}})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:1233
#  [152] *(α::Number, B::AbstractMatrix, C::AbstractMatrix, x::AbstractVector)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:1216
#  [153] *(α::Number, u::AbstractVector, tv::Union{LinearAlgebra.Adjoint{T, var"#s970"}, LinearAlgebra.Transpose{T, var"#s970"}} where {T, var"#s970"<:(AbstractVector)})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:1162
#  [154] *(A::Number, B::AbstractArray)
#      @ arraymath.jl:21
#  [155] *(y::Real, x::Dates.Period)
#      @ Dates ~/julia/usr/share/julia/stdlib/v1.9/Dates/src/periods.jl:91
#  [156] *(z::Complex, w::Complex)
#      @ complex.jl:293
#  [157] *(A::LinearAlgebra.Hermitian, x::Real)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/symmetric.jl:606
#  [158] *(A::LinearAlgebra.Hermitian{ComplexF64, SparseArrays.SparseMatrixCSC{ComplexF64, Ti}}, B::Union{SparseArrays.SparseMatrixCSC{ComplexF64, Ti}, SparseArrays.SparseVector{ComplexF64, Ti}}) where Ti
#      @ SparseArrays.CHOLMOD ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/solvers/cholmod.jl:1685
#  [159] *(A::LinearAlgebra.Hermitian{Float64, SparseArrays.SparseMatrixCSC{Float64, Ti}}, B::Union{SparseArrays.SparseMatrixCSC{Float64, Ti}, SparseArrays.SparseVector{Float64, Ti}}) where Ti
#      @ SparseArrays.CHOLMOD ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/solvers/cholmod.jl:1687
#  [160] *(A::LinearAlgebra.LQ{TA, S, C} where {S<:AbstractMatrix{TA}, C<:AbstractVector{TA}}, B::AbstractVecOrMat{TB}) where {TA, TB}
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/lq.jl:198
#  [161] *(x::AbstractIrrational, y::AbstractIrrational)
#      @ irrationals.jl:161
#  [162] *(J1::LinearAlgebra.UniformScaling, J2::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/uniformscaling.jl:257
#  [163] *(J::LinearAlgebra.UniformScaling, B::BitMatrix)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/uniformscaling.jl:259
#  [164] *(J::LinearAlgebra.UniformScaling, x::Number)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/uniformscaling.jl:264
#  [165] *(x::LinearAlgebra.UniformScaling, H::LinearAlgebra.UpperHessenberg)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/hessenberg.jl:120
#  [166] *(J::LinearAlgebra.UniformScaling, A::AbstractVecOrMat)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/uniformscaling.jl:262
#  [167] *(tA::LinearAlgebra.Transpose{<:Any, <:StridedMatrix{T}}, x::StridedVector{S}) where {T<:Union{Float32, Float64, ComplexF64, ComplexF32}, S}
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:84
#  [168] *(transx::LinearAlgebra.Transpose{<:Any, <:StridedVector{T}}, y::StridedVector{T}) where T<:Union{ComplexF64, ComplexF32}
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:43
#  [169] *(tA::LinearAlgebra.Transpose{<:Any, <:SparseArrays.AbstractSparseMatrixCSC}, x::Union{StridedVector, BitVector})
#      @ SparseArrays ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:82
#  [170] *(A::LinearAlgebra.Transpose{<:Any, <:SparseArrays.AbstractSparseMatrixCSC}, B::Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange, LinearAlgebra.LowerTriangular{Tv, <:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange}}, LinearAlgebra.UpperTriangular{Tv, <:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange}}} where {Tv, Ti})
#      @ SparseArrays ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:159
#  [171] *(tA::LinearAlgebra.Transpose{<:Any, <:SparseArrays.AbstractSparseMatrixCSC}, B::Union{LinearAlgebra.Adjoint{<:Any, <:Union{LinearAlgebra.LowerTriangular, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix, BitMatrix}}, LinearAlgebra.LowerTriangular, LinearAlgebra.Transpose{<:Any, <:Union{LinearAlgebra.LowerTriangular, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix, BitMatrix}}, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix, BitMatrix})
#      @ SparseArrays ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:84
#  [172] *(tA::LinearAlgebra.Transpose{<:Any, <:SparseArrays.AbstractSparseMatrixCSC}, x::SparseArrays.AbstractSparseVector)
#      @ SparseArrays ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/sparsevector.jl:1953
#  [173] *(tA::LinearAlgebra.Transpose{<:Any, <:Union{LinearAlgebra.LowerTriangular{Ta, S} where S<:AbstractMatrix{Ta}, LinearAlgebra.UnitLowerTriangular{Ta, S} where S<:AbstractMatrix{Ta}, LinearAlgebra.UnitUpperTriangular{Ta, S} where S<:AbstractMatrix{Ta}, LinearAlgebra.UpperTriangular{Ta, S} where S<:AbstractMatrix{Ta}, StridedArray{Ta, 2}}}, x::SparseArrays.AbstractSparseVector{Tx}) where {Ta, Tx}
#      @ SparseArrays ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/sparsevector.jl:1776
#  [174] *(u::LinearAlgebra.Transpose{T, <:AbstractVector} where T, v::LinearAlgebra.Adjoint{<:Any, <:LinearAlgebra.Transpose{T, <:AbstractVector} where T})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/adjtrans.jl:447
#  [175] *(u::LinearAlgebra.Transpose{T, <:AbstractVector}, v::AbstractVector{T}) where T<:Real
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/adjtrans.jl:434
#  [176] *(u::LinearAlgebra.Transpose{T, <:AbstractVector} where T, D::LinearAlgebra.Diagonal)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/diagonal.jl:794
#  [177] *(x::LinearAlgebra.Transpose{T, <:AbstractVector} where T, D::LinearAlgebra.Diagonal, y::AbstractVector)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/diagonal.jl:796
#  [178] *(v::LinearAlgebra.Transpose{T, <:AbstractVector} where T, A::LinearAlgebra.AbstractTriangular)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/triangular.jl:1453
#  [179] *(u::LinearAlgebra.Transpose{T, <:AbstractVector} where T, v::LinearAlgebra.Transpose{<:Any, <:LinearAlgebra.Adjoint{T, <:AbstractVector} where T})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/adjtrans.jl:449
#  [180] *(A::LinearAlgebra.Transpose{<:Any, <:SparseArrays.AbstractSparseMatrixCSC}, B::LinearAlgebra.Transpose{<:Any, <:SparseArrays.AbstractSparseMatrixCSC})
#      @ SparseArrays ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:162
#  [181] *(tA::LinearAlgebra.Transpose{<:Any, <:AbstractMatrix{T}}, x::AbstractVector{S}) where {T, S}
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:88
#  [182] *(u::LinearAlgebra.Transpose{T, <:AbstractVector} where T, v::LinearAlgebra.Transpose{T, <:AbstractVector} where T)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/adjtrans.jl:443
#  [183] *(x::LinearAlgebra.Transpose{T, <:AbstractVector} where T, A::AbstractMatrix)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:120
#  [184] *(adjQ::LinearAlgebra.Adjoint{<:Any, <:LinearAlgebra.AbstractQ}, B::StridedVecOrMat)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/qr.jl:723
#  [185] *(adjA::LinearAlgebra.Adjoint{<:Any, <:StridedMatrix{T}}, x::StridedVector{S}) where {T<:Union{Float32, Float64, ComplexF64, ComplexF32}, S}
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:99
#  [186] *(adjA::LinearAlgebra.Adjoint{<:Any, <:LinearAlgebra.LQPackedQ}, B::StridedVecOrMat)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/lq.jl:217
#  [187] *(Q::LinearAlgebra.Adjoint{<:Any, <:LinearAlgebra.AbstractQ}, B::Union{LinearAlgebra.Bidiagonal, LinearAlgebra.SymTridiagonal, LinearAlgebra.Tridiagonal})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:312
#  [188] *(adjA::LinearAlgebra.Adjoint{<:Any, <:SparseArrays.AbstractSparseMatrixCSC}, x::Union{StridedVector, BitVector})
#      @ SparseArrays ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:78
#  [189] *(A::LinearAlgebra.Adjoint{<:Any, <:SparseArrays.AbstractSparseMatrixCSC}, B::Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange, LinearAlgebra.LowerTriangular{Tv, <:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange}}, LinearAlgebra.UpperTriangular{Tv, <:Union{SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, SubArray{Tv, 2, <:SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, Tuple{Base.Slice{Base.OneTo{Int64}}, I}} where I<:AbstractUnitRange}}} where {Tv, Ti})
#      @ SparseArrays ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:160
#  [190] *(adjA::LinearAlgebra.Adjoint{<:Any, <:SparseArrays.AbstractSparseMatrixCSC}, B::Union{LinearAlgebra.Adjoint{<:Any, <:Union{LinearAlgebra.LowerTriangular, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix, BitMatrix}}, LinearAlgebra.LowerTriangular, LinearAlgebra.Transpose{<:Any, <:Union{LinearAlgebra.LowerTriangular, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix, BitMatrix}}, LinearAlgebra.UnitLowerTriangular, LinearAlgebra.UnitUpperTriangular, LinearAlgebra.UpperTriangular, StridedMatrix, BitMatrix})
#      @ SparseArrays ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:80
#  [191] *(adjA::LinearAlgebra.Adjoint{<:Any, <:Union{LinearAlgebra.LowerTriangular{Ta, S} where S<:AbstractMatrix{Ta}, LinearAlgebra.UnitLowerTriangular{Ta, S} where S<:AbstractMatrix{Ta}, LinearAlgebra.UnitUpperTriangular{Ta, S} where S<:AbstractMatrix{Ta}, LinearAlgebra.UpperTriangular{Ta, S} where S<:AbstractMatrix{Ta}, StridedArray{Ta, 2}}}, x::SparseArrays.AbstractSparseVector{Tx}) where {Ta, Tx}
#      @ SparseArrays ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/sparsevector.jl:1814
#  [192] *(adjA::LinearAlgebra.Adjoint{<:Any, <:SparseArrays.AbstractSparseMatrixCSC}, x::SparseArrays.AbstractSparseVector)
#      @ SparseArrays ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/sparsevector.jl:1956
#  [193] *(adjA::LinearAlgebra.Adjoint{<:Any, <:StridedMatrix{T} where T}, Q::LinearAlgebra.LQPackedQ)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/lq.jl:305
#  [194] *(u::LinearAlgebra.Adjoint{<:Number, <:AbstractVector}, v::AbstractVector{<:Number})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/adjtrans.jl:433
#  [195] *(u::LinearAlgebra.Adjoint{T, <:AbstractVector} where T, v::LinearAlgebra.Transpose{<:Any, <:LinearAlgebra.Adjoint{T, <:AbstractVector} where T})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/adjtrans.jl:450
#  [196] *(a::AbstractVector, tB::LinearAlgebra.Transpose{T, <:AbstractMatrix} where T)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:60
#  [197] *(adjA::LinearAlgebra.Adjoint{<:Any, <:StridedVecOrMat}, Q::LinearAlgebra.AbstractQ)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/qr.jl:839
#  [198] *(Q::LinearAlgebra.Adjoint{<:Any, <:LinearAlgebra.AbstractQ}, B::LinearAlgebra.AbstractQ)
# ...
#  [200] *(adjA::LinearAlgebra.Adjoint{<:Any, <:StridedVecOrMat}, adjQ::LinearAlgebra.Adjoint{<:Any, <:LinearAlgebra.AbstractQ})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/qr.jl:846
#  [201] *(adjQ::LinearAlgebra.Adjoint{<:Any, <:LinearAlgebra.AbstractQ}, adjB::LinearAlgebra.Adjoint{<:Any, <:StridedVecOrMat})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/qr.jl:737
#  [202] *(u::LinearAlgebra.Adjoint{T, <:AbstractVector} where T, v::LinearAlgebra.Adjoint{<:Any, <:LinearAlgebra.Transpose{T, <:AbstractVector} where T})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/adjtrans.jl:448
#  [203] *(adjA::LinearAlgebra.Adjoint{<:Any, <:LinearAlgebra.LQPackedQ}, adjB::LinearAlgebra.Adjoint{<:Any, <:StridedVecOrMat})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/lq.jl:237
#  [204] *(adjA::LinearAlgebra.Adjoint{<:Any, <:StridedMatrix{T} where T}, adjQ::LinearAlgebra.Adjoint{<:Any, <:LinearAlgebra.LQPackedQ})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/lq.jl:274
#  [205] *(Q::LinearAlgebra.Adjoint{<:Any, <:LinearAlgebra.AbstractQ}, B::LinearAlgebra.Adjoint{<:Any, <:LinearAlgebra.AbstractQ})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:346
#  [206] *(u::LinearAlgebra.Adjoint{T, <:AbstractVector} where T, A::LinearAlgebra.Adjoint{<:Any, <:LinearAlgebra.AbstractQ})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/qr.jl:835
#  [207] *(A::LinearAlgebra.Adjoint{<:Any, <:SparseArrays.AbstractSparseMatrixCSC}, B::LinearAlgebra.Adjoint{<:Any, <:SparseArrays.AbstractSparseMatrixCSC})
#      @ SparseArrays ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:161
#  [208] *(tu::Union{LinearAlgebra.Adjoint{T, var"#s970"}, LinearAlgebra.Transpose{T, var"#s970"}} where {T, var"#s970"<:(AbstractVector)}, B::Union{LinearAlgebra.Adjoint{T, var"#s970"}, LinearAlgebra.Transpose{T, var"#s970"}} where {T, var"#s970"<:(AbstractMatrix)}, v::AbstractVector)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:1153
#  [209] *(u::LinearAlgebra.Adjoint{T, <:AbstractVector} where T, v::LinearAlgebra.Adjoint{T, <:AbstractVector} where T)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/adjtrans.jl:442
#  [210] *(adjA::LinearAlgebra.Adjoint{<:Any, <:SparseArrays.CHOLMOD.Sparse}, B::SparseArrays.CHOLMOD.Sparse)
#      @ SparseArrays.CHOLMOD ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/solvers/cholmod.jl:1100
#  [211] *(Q::LinearAlgebra.Adjoint{<:Any, <:LinearAlgebra.AbstractQ}, B::LinearAlgebra.Diagonal)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:314
#  [212] *(A::Union{LinearAlgebra.Adjoint{T, var"#s970"}, LinearAlgebra.Transpose{T, var"#s970"}} where {T, var"#s970"<:(AbstractMatrix)}, D::LinearAlgebra.Diagonal)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/diagonal.jl:255
#  [213] *(u::LinearAlgebra.Adjoint{T, <:AbstractVector} where T, D::LinearAlgebra.Diagonal)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/diagonal.jl:793
#  [214] *(x::LinearAlgebra.Adjoint{T, <:AbstractVector} where T, D::LinearAlgebra.Diagonal, y::AbstractVector)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/diagonal.jl:795
#  [215] *(Q::LinearAlgebra.Adjoint{<:Any, <:LinearAlgebra.AbstractQ}, B::LinearAlgebra.AbstractTriangular)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:310
#  [216] *(v::LinearAlgebra.Adjoint{T, <:AbstractVector} where T, A::LinearAlgebra.AbstractTriangular)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/triangular.jl:1452
#  [217] *(adjA::LinearAlgebra.Adjoint{<:Any, <:SparseArrays.CHOLMOD.Sparse}, B::VecOrMat)
#      @ SparseArrays.CHOLMOD ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/solvers/cholmod.jl:1112
#  [218] *(u::Union{LinearAlgebra.Adjoint{T, var"#s970"}, LinearAlgebra.Transpose{T, var"#s970"}} where {T, var"#s970"<:(AbstractVector)}, v::AbstractVector)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/adjtrans.jl:435
#  [219] *(x::LinearAlgebra.Adjoint{T, <:AbstractVector} where T, A::AbstractMatrix)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:119
#  [220] *(tu::Union{LinearAlgebra.Adjoint{T, var"#s970"}, LinearAlgebra.Transpose{T, var"#s970"}} where {T, var"#s970"<:(AbstractVector)}, B::AbstractMatrix, v::AbstractVector)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:1152
#  [221] *(tv::Union{LinearAlgebra.Adjoint{T, var"#s970"}, LinearAlgebra.Transpose{T, var"#s970"}} where {T, var"#s970"<:(AbstractVector)}, B::AbstractMatrix, C::AbstractMatrix)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:1167
#  [222] *(vt::Union{LinearAlgebra.Adjoint{T, var"#s970"}, LinearAlgebra.Transpose{T, var"#s970"}} where {T, var"#s970"<:(AbstractVector)}, B::AbstractMatrix, x::AbstractVector, δ::Number)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:1224
#  [223] *(vt::Union{LinearAlgebra.Adjoint{T, var"#s970"}, LinearAlgebra.Transpose{T, var"#s970"}} where {T, var"#s970"<:(AbstractVector)}, B::AbstractMatrix, C::AbstractMatrix, δ::Number)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:1225
#  [224] *(vt::Union{LinearAlgebra.Adjoint{T, var"#s970"}, LinearAlgebra.Transpose{T, var"#s970"}} where {T, var"#s970"<:(AbstractVector)}, B::AbstractMatrix, C::AbstractMatrix, D::AbstractMatrix)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:1228
#  [225] *(vt::Union{LinearAlgebra.Adjoint{T, var"#s970"}, LinearAlgebra.Transpose{T, var"#s970"}} where {T, var"#s970"<:(AbstractVector)}, B::AbstractMatrix, C::AbstractMatrix, x::AbstractVector)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:1229
#  [226] *(adjA::LinearAlgebra.Adjoint{<:Any, <:AbstractMatrix{T}}, x::AbstractVector{S}) where {T, S}
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:103
#  [227] *(A::LinearAlgebra.UnitUpperTriangular, x::Number)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/triangular.jl:851
#  [228] *(A::AbstractArray, B::Number)
#      @ arraymath.jl:24
#  [229] *(A::LinearAlgebra.UnitUpperTriangular, B::LinearAlgebra.UpperTriangular)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/triangular.jl:1326
#  [230] *(A::LinearAlgebra.UnitUpperTriangular, B::LinearAlgebra.UnitUpperTriangular)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/triangular.jl:1340
#  [231] *(A::LinearAlgebra.AbstractTriangular, B::LinearAlgebra.AbstractTriangular)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/triangular.jl:1400
#  [232] *(A::AbstractMatrix, B::LinearAlgebra.AbstractTriangular)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/triangular.jl:1445
#  [233] *(A::LinearAlgebra.UnitUpperTriangular, D::LinearAlgebra.Diagonal)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/diagonal.jl:541
#  [234] *(A::LinearAlgebra.AbstractTriangular, D::LinearAlgebra.Diagonal)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/diagonal.jl:800
#  [235] *(A::AbstractMatrix, D::LinearAlgebra.Diagonal)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/diagonal.jl:247
#  [236] *(A::LinearAlgebra.AbstractTriangular, B::AbstractVector)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/triangular.jl:1408
#  [237] *(A::LinearAlgebra.AbstractTriangular, B::AbstractMatrix)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/triangular.jl:1408
#  [238] *(A::SparseArrays.CHOLMOD.Sparse, B::SparseArrays.CHOLMOD.Sparse)
#      @ SparseArrays.CHOLMOD ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/solvers/cholmod.jl:1075
#  [239] *(A::SparseArrays.CHOLMOD.Sparse, B::SparseArrays.CHOLMOD.Dense)
#      @ SparseArrays.CHOLMOD ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/solvers/cholmod.jl:1076
#  [240] *(A::SparseArrays.CHOLMOD.Sparse, B::VecOrMat)
#      @ SparseArrays.CHOLMOD ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/solvers/cholmod.jl:1077
#  [241] *(A::SparseArrays.CHOLMOD.Sparse{Tv}, adjB::LinearAlgebra.Adjoint{Tv, SparseArrays.CHOLMOD.Sparse{Tv}}) where Tv<:Float64
#      @ SparseArrays.CHOLMOD ~/julia/usr/share/julia/stdlib/v1.9/SparseArrays/src/solvers/cholmod.jl:1079
#  [242] *(u::AbstractVector, v::Union{LinearAlgebra.Adjoint{T, var"#s970"}, LinearAlgebra.Transpose{T, var"#s970"}} where {T, var"#s970"<:(AbstractVector)})
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/adjtrans.jl:439
#  [243] *(u::AbstractVector, tv::Union{LinearAlgebra.Adjoint{T, var"#s970"}, LinearAlgebra.Transpose{T, var"#s970"}} where {T, var"#s970"<:(AbstractVector)}, C::AbstractMatrix)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:1164
#  [244] *(u::AbstractVector, tv::Union{LinearAlgebra.Adjoint{T, var"#s970"}, LinearAlgebra.Transpose{T, var"#s970"}} where {T, var"#s970"<:(AbstractVector)}, γ::Number)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:1163
#  [245] *(A::AbstractMatrix, B::AbstractMatrix)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:139
#  [246] *(A::AbstractMatrix, B::AbstractMatrix, γ::Number)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:1156
#  [247] *(A::AbstractMatrix, B::AbstractMatrix, x::AbstractVector)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:1150
#  [248] *(A::AbstractMatrix{T}, x::AbstractVector{S}) where {T, S}
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:54
#  [249] *(A::AbstractMatrix, x::AbstractVector, γ::Number)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:1155
#  [250] *(A::AbstractMatrix, B::AbstractMatrix, C::AbstractMatrix)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:1166
#  [251] *(A::AbstractMatrix, x::AbstractVector, γ::Number, δ::Number)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:1221
#  [252] *(A::AbstractMatrix, B::AbstractMatrix, γ::Number, δ::Number)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:1222
#  [253] *(A::AbstractMatrix, B::AbstractMatrix, x::AbstractVector, δ::Number)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:1223
#  [254] *(A::AbstractMatrix, B::AbstractMatrix, C::AbstractMatrix, x::AbstractVector)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:1227
#  [255] *(A::AbstractMatrix, B::AbstractMatrix, C::AbstractMatrix, δ::Number)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:1232
#  [256] *(A::AbstractMatrix, B::AbstractMatrix, C::AbstractMatrix, D::AbstractMatrix)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:1235
#  [257] *(a::AbstractVector, adjB::LinearAlgebra.Adjoint{T, <:AbstractMatrix} where T)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:61
#  [258] *(a::AbstractVector, B::AbstractMatrix)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:62
#  [259] *(x::P, y::Real) where P<:Dates.Period
#      @ Dates ~/julia/usr/share/julia/stdlib/v1.9/Dates/src/periods.jl:90
#  [260] *(x::Dates.Period, r::AbstractRange{<:Real})
#      @ Dates ~/julia/usr/share/julia/stdlib/v1.9/Dates/src/ranges.jl:67
#  [261] *(A::Dates.Period, B::AbstractArray)
#      @ Dates ~/julia/usr/share/julia/stdlib/v1.9/Dates/src/periods.jl:93
#  [262] *(R::LinearAlgebra.Rotation{S}, G::LinearAlgebra.Givens{T}) where {S, T}
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/givens.jl:425
#  [263] *(y::AbstractFloat, x::Bool)
#      @ bool.jl:182
#  [264] *(x::BigInt, c::Union{UInt16, UInt32, UInt64, UInt8})
#      @ Base.GMP gmp.jl:549
#  [265] *(x::BigInt, c::Union{Int16, Int32, Int64, Int8})
#      @ Base.GMP gmp.jl:551
#  [266] *(x::BigInt, y::BigInt)
#      @ Base.GMP gmp.jl:490
#  [267] *(a::BigInt, b::BigInt, c::BigInt)
#      @ Base.GMP gmp.jl:530
#  [268] *(a::BigInt, b::BigInt, c::BigInt, d::BigInt)
#      @ Base.GMP gmp.jl:531
#  [269] *(a::BigInt, b::BigInt, c::BigInt, d::BigInt, e::BigInt)
#      @ Base.GMP gmp.jl:532
#  [270] *(c::BigInt, x::BigFloat)
#      @ Base.MPFR mpfr.jl:431
#  [271] *(::Missing)
#      @ missing.jl:101
#  [272] *(::Missing, ::Number)
#      @ missing.jl:123
#  [273] *(d::Missing, x::Union{AbstractChar, AbstractString})
#      @ missing.jl:182
#  [274] *(::Missing, ::Missing)
#      @ missing.jl:122
#  [275] *(r::Regex)
#      @ regex.jl:780
#  [276] *(r1::Union{Regex, AbstractChar, AbstractString}, rs::Union{Regex, AbstractChar, AbstractString}...)
#      @ regex.jl:759
#  [277] *(z::Complex{Bool}, x::Bool)
#      @ complex.jl:307
#  [278] *(z::Complex, x::Bool)
#      @ complex.jl:314
#  [279] *(z::Complex{Bool}, x::Real)
#      @ complex.jl:325
#  [280] *(z::Complex, x::Real)
#      @ complex.jl:337
#  [281] *(x::Bool, y::T) where T<:AbstractFloat
#      @ bool.jl:179
#  [282] *(x::Bool, y::AbstractIrrational)
#      @ irrationals.jl:163
#  [283] *(x::Bool, y::Bool)
#      @ bool.jl:168
#  [284] *(a::Integer, b::Integer)
#      @ int.jl:1038
#  [285] *(x::Bool, z::Complex{Bool})
#      @ complex.jl:306
#  [286] *(x::Real, z::Complex{Bool})
#      @ complex.jl:324
#  [287] *(x::Bool, z::Complex)
#      @ complex.jl:313
#  [288] *(x::Real, z::Complex)
#      @ complex.jl:336
#  [289] *(B::BitMatrix, J::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/uniformscaling.jl:258
#  [290] *(x::AbstractMatrix{<:Number})
#      @ abstractarraymath.jl:221
#  [291] *(A::AbstractMatrix, J::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/uniformscaling.jl:260
#  [292] *(v::AbstractVector, J::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/uniformscaling.jl:261
#  [293] *(x::BigFloat, c::Union{UInt16, UInt32, UInt64, UInt8})
#      @ Base.MPFR mpfr.jl:402
#  [294] *(x::BigFloat, c::Union{Int16, Int32, Int64, Int8})
#      @ Base.MPFR mpfr.jl:410
#  [295] *(x::BigFloat, c::Union{Float16, Float32, Float64})
#      @ Base.MPFR mpfr.jl:418
#  [296] *(x::BigFloat, y::BigFloat)
#      @ Base.MPFR mpfr.jl:395
#  [297] *(x::BigFloat, c::BigInt)
#      @ Base.MPFR mpfr.jl:426
#  [298] *(a::BigFloat, b::BigFloat, c::BigFloat)
#      @ Base.MPFR mpfr.jl:567
#  [299] *(a::BigFloat, b::BigFloat, c::BigFloat, d::BigFloat)
#      @ Base.MPFR mpfr.jl:573
#  [300] *(a::BigFloat, b::BigFloat, c::BigFloat, d::BigFloat, e::BigFloat)
#      @ Base.MPFR mpfr.jl:580
#  [301] *(x::Rational{BigInt}, y::Rational{BigInt})
#      @ Base.GMP.MPQ gmp.jl:1030
#  [302] *(x::Rational, y::Rational)
#      @ rational.jl:347
#  [303] *(x::Number)
#      @ operators.jl:516
#  [304] *(α::Number, vt::Union{LinearAlgebra.Adjoint{T, var"#s970"}, LinearAlgebra.Transpose{T, var"#s970"}} where {T, var"#s970"<:(AbstractVector)}, C::AbstractMatrix, x::AbstractVector)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:1217
#  [305] *(x::T, y::T) where T<:Number
#      @ promotion.jl:486
#  [306] *(x::Number, y::Number)
#      @ promotion.jl:411
#  [307] *(α::Number, β::Number, C::AbstractMatrix, D::AbstractMatrix)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:1215
#  [308] *(α::Number, β::Number, C::AbstractMatrix, x::AbstractVector)
#      @ LinearAlgebra ~/julia/usr/share/julia/stdlib/v1.9/LinearAlgebra/src/matmul.jl:1214
#  [309] *(a, b, c, xs...)
#      @ operators.jl:578

# %%
@which((1+2im)*(2+3im))
# Out:
# *(z::Complex, w::Complex)
#      @ Base complex.jl:293

# %%
#download(url, "covid_death_data.csv")
#download(url, "covid_confirmed_data.csv")
#download(url, "covid_california_data.csv")
download(url, "covid_usa_national_data.csv")
# Out:
# "covid_usa_national_data.csv"

# %%
readdir()
# Out:
# 118-element Vector{String}:
#  ".ICEauthority"
#  ".Xauthority"
#  ".Xresources"
#  ".bash_history"
#  ".bash_logout"
#  ".bashrc"
#  ".cache"
#  ".conda"
#  ".config"
#  ".dbus"
#  ".gnupg"
#  ".gsutil"
#  ".ipynb_checkpoints"
#  ⋮
#  "staticVPN.key"
#  "the-littlest-jupyterhub"
#  "tljh.jupytr.org-bootstrap.py"
#  "usrlocal"
#  "versor"
#  "webrtc"
#  "wordpress.journals.tar.gz"
#  "wordpress.zip"
#  "wp_options_backup.csv"
#  "xv_3.32.0.5-1_amd64.deb"
#  "xv_mac_11.10.1.70315_release.pkg"
#  "xv_mac_11.12.0.70542_release.pkg"

# %%
using Pkg
Pkg.add("CSV")
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`

# %%
using CSV
Pkg.add("DataFrames")
# Out:
#    Resolving package versions...
# ┌ Warning: could not download https://pkg.julialang.org/registries
# │   exception = RequestError: SSL connection timeout while requesting https://pkg.julialang.org/registries
# └ @ Pkg.Registry ~/julia/usr/share/julia/stdlib/v1.9/Pkg/src/Registry/Registry.jl:69
#    Installed Reexport ─────────── v1.2.2
#    Installed Crayons ──────────── v4.1.1
#    Installed LaTeXStrings ─────── v1.3.0
#    Installed SnoopPrecompile ──── v1.0.3
#    Installed InvertedIndices ──── v1.3.0
#    Installed DataFrames ───────── v1.5.0
#    Installed SortingAlgorithms ── v1.1.0
#    Installed Formatting ───────── v0.4.2
#    Installed StringManipulation ─ v0.3.0
#    Installed Missings ─────────── v1.1.0
#    Installed DataStructures ───── v0.18.13
#    Installed PrettyTables ─────── v2.2.4
#     Updating `~/.julia/environments/v1.9/Project.toml`
#   [a93c6f00] + DataFrames v1.5.0
#     Updating `~/.julia/environments/v1.9/Manifest.toml`
#   [a8cc5b0e] + Crayons v4.1.1
#   [a93c6f00] + DataFrames v1.5.0
#   [864edb3b] + DataStructures v0.18.13
#   [59287772] + Formatting v0.4.2
#   [41ab1584] + InvertedIndices v1.3.0
#   [b964fa9f] + LaTeXStrings v1.3.0
#   [e1d29d7a] + Missings v1.1.0
#   [08abe8d2] + PrettyTables v2.2.4
#   [189a3867] + Reexport v1.2.2
#   [66db9d55] + SnoopPrecompile v1.0.3
#   [a2af1166] + SortingAlgorithms v1.1.0
#   [892a3eda] + StringManipulation v0.3.0
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics v1.9.0
#   [bea87d4a] + SuiteSparse_jll v5.10.1+6
# Precompiling project...
#   ✓ Reexport
#   ✓ SuiteSparse_jll
#   ✓ LaTeXStrings
#   ✓ SnoopPrecompile
#   ✓ InvertedIndices
#   ✓ Missings
#   ✓ Formatting
#   ✓ Statistics
#   ✓ Crayons
#   ✓ DataStructures
#   ✓ StringManipulation
#   ✓ SortingAlgorithms
#   ✓ PrettyTables
#   ✓ DataFrames
#   14 dependencies successfully precompiled in 166 seconds. 33 already precompiled.

# %%
using DataFrames
#recovered_data = CSV.read("covid_recovered_data.csv", DataFrame)
#death_data = CSV.read("covid_death_data.csv", DataFrame)
#confirmed_data = CSV.read("covid_confirmed_data.csv", DataFrame)
#california_data = CSV.read("covid_california_data.csv", DataFrame)
usa_national_data = CSV.read("covid_usa_national_data.csv", DataFrame)
# Out:
# 420×17 DataFrame
#  Row │ date        death    deathIncrease  inIcuCumulative  inIcuCurrently  ho ⋯
#      │ Date        Int64?   Int64          Int64?           Int64?          In ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 2021-03-07   515151            842            45475            8134     ⋯
#    2 │ 2021-03-06   514309           1680            45453            8409
#    3 │ 2021-03-05   512629           2221            45373            8634
#    4 │ 2021-03-04   510408           1743            45293            8970
#    5 │ 2021-03-03   508665           2449            45214            9359     ⋯
#    6 │ 2021-03-02   506216           1728            45084            9465
#    7 │ 2021-03-01   504488           1241            44956            9595
#    8 │ 2021-02-28   503247           1051            44907            9802
#    9 │ 2021-02-27   502196           1847            44875           10114     ⋯
#   10 │ 2021-02-26   500349           2141            44791           10466
#   11 │ 2021-02-25   498208           3138            44636           10846
#   ⋮  │     ⋮          ⋮           ⋮               ⋮               ⋮            ⋱
#  411 │ 2020-01-22  missing              0          missing         missing
#  412 │ 2020-01-21  missing              0          missing         missing     ⋯
#  413 │ 2020-01-20  missing              0          missing         missing
#  414 │ 2020-01-19  missing              0          missing         missing
#  415 │ 2020-01-18  missing              0          missing         missing
#  416 │ 2020-01-17  missing              0          missing         missing     ⋯
#  417 │ 2020-01-16  missing              0          missing         missing
#  418 │ 2020-01-15  missing              0          missing         missing
#  419 │ 2020-01-14  missing              0          missing         missing
#  420 │ 2020-01-13  missing              0          missing         missing     ⋯
#                                                  12 columns and 399 rows omitted

# %% [markdown]
# **Building the SIR model of the Pandemic**
#
# Variables for Model 1
#
# $t$ = the time in days with t=0 at the start of observation
#
# $S$ = the number of susceptible individuals
#
# $I$ = the number of infectious individual
#
# $R$ = the number of removed individuals
#
# These variables keep track of the number of individuals in each of the compartment.
# Time t is the independent variable; and $S$, $I$, and $R$ are dependent on time, they are functions of time, but they are not
# functions given by explicit formulas such as $y = x^3$. Although we will be able to compute $S = S[t]$, there wouldn't be
# an explicit formula for $S$ in terms of $t$.
#
# **Derivation of the Equations of Change**
#
# Now we want to add a mathematical description of the way individuals move among the susceptible, infectious, and removed compartments.
# This will add two parameters to our model, $a$ and $b$, that are specific to a particular $S$-$I$-$R$ disease.
#
# Parameters are letters that have a fixed value during the entire problem but can change from one problem to the next.
#
# We begin with the simplest change - how one recovers.
#
# A person with COVID-19 is infectious for about $x$ number of days, to either be moved away from infectious state, to recovered, or died during.
#
# So, the number of people added to the removed compartment tomorrow is $\frac{1}{x}$th of the infectious compartment today.
#
# New people in $R$-compartment tomorrow = $\frac{1}{x}I$
#
# A general disease, from which one recovers and gains immunity, has the day's change in the recovered compartment given by,
#
# New people in $R$-compartment tomorrow =$b I$
#
# where the parameter $b$ controls how quickly people recover, or $\frac{1}{b}$ is the number of days one stays in the infectious compatment.
#
# For COVID-19, $b=\frac{1}{x}$
#
# Notice that the units of the right side fo the above equation for the day's change in $R$ are "number of people per day."
#
# The next change is how one spreads the disease. If one is infectious with COVID-19, and one sit through a whole class next to a person
# who is susceptible, then one will probably spread the disease to that person. If one sit through class next to an immune person, one will not spread the disease.
#
# $c$ = the average number of contacts per infective during the whole infectious period
#
# The parameter $c$ is the average total number of "close" contacts per infective. We want a parameter that describes the contagiousness. The paramter. $c$ is a combined measure of the level of mixing in the population and the contagiousness of the disease. The proble is:
# How do we measure $c$? Later we will see that $c$ can be measured indirectly with the help of calculus.
#
# The number of contacts per infective each day is given by $a = c \cdot b$, because $b$ equals 1/(the number of days infectious).
# This means that if $I$ people are infectious on a particular day,
#
# $a \cdot I$ = the total number of adequate contacts per day
#
# Only the contacts with susceptable people result in a new case of the disease, so we multiply this total times the fraction of
# susceptible people. Our final parameter, $n$, is the fixed total population. This makes the number of new cases of the disease,
#
# new cases tomorrow = $a \frac{S}{n} I$
#
# where $n$ =the fixed size of the population
#
# **Parameters of the S-I-R Model**
#
# $b = \frac{1}{x}$ (x: the average number of days infectious)
#
# $c$ = the average total number of contacts per infectious person
#
# $a = b \cdot c$ the daily rate of contacts per infective
#
# $n$ = the total number of people in the population
#
# Units of $a, b, c$:
#
# $c$ in average number of close contacts per infective
#
# $b$ in $\frac{1}{days} $ or $\frac{1}{b}$ = number of days infective
#
# $a$ in $\frac{number (of adequate contacts)}{number(infectives) \times days (infectious)}$
#
# Fig. 2.2 Compartements with Parameters
#
# $[S] ^a \rightarrow [I] ^b \rightarrow [R] $
#
#
# **The First Equations of Change**
#
#   tomorrow's increase in $S = - a\frac{S}{n} I$
#
#   tomorrow's increase in $I = a\frac{S}{n} I - b I$
#
#   tomorrow's increase in $R = bI$
